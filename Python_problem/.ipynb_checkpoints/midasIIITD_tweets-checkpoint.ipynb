# %% [markdown]
# ### Installing useful libraries such as tweepy and jsonlines

# %%
# !pip3 install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/site-packages (3.7.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.7/site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/site-packages (from tweepy) (1.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.7/site-packages (from tweepy) (2.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2019.3.9)

# %%
# !pip3 install jsonlines
# Out:
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.7/site-packages (1.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from jsonlines) (1.11.0)

# %% [markdown]
# ### Importing useful libraries

# %%
import tweepy 
import json
import jsonlines
import pandas as pd
import datetime

# %% [markdown]
# ### keys to fetch data using Twitter API

# %%
consumer_key = "" 
consumer_secret = ""
access_key = ""
access_secret = ""

# %% [markdown]
# #### Authentication and API call

# %%
# Authorization to consumer key and consumer secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
# Access to user's access key and access secret 
auth.set_access_token(access_key, access_secret) 
  
# Calling api 
api = tweepy.API(auth)

# %% [markdown]
# #### This code cell fetches all the information of each tweet of the user midasIIITD

# %%
whole_info = dict()
tweet_count = 0
for status in tweepy.Cursor(api.user_timeline, id="midasIIITD").items():
    tweet_count += 1
    whole_info[tweet_count] = status._json

# %%
# number of tweets by midasIIITD
len(whole_info)
# Out:
# 347

# %% [markdown]
# #### the cell below first dumps the information extracted into a json and then loads it into a python object known as  whole_info and then writes that python object into a json lines file known as twitter_username.jsonl

# %%
whole_info = json.loads(json.dumps(whole_info))
with jsonlines.open('twitter_username.jsonl', 'w') as outfile:
    outfile.write(whole_info)

# %% [markdown]
# #### the following cell dumps all the information into a python list, this is done to extract specific information of tweets

# %%
info = list()
with jsonlines.open('twitter_username.jsonl', 'r') as readfile:
    for tweet in readfile:
        info.append(tweet)
# info[0]

# %%
type(info[0])
# Out:
# dict

# %%
# assigning the info element to a variable name username_whole_twitter_info
username_whole_twitter_info = info[0]

# %%
# confirming the number of tweets
len(username_whole_twitter_info)
# Out:
# 347

# %% [markdown]
# #### the block below is used to spilt date and time and to convert the time into 12 hr format and returns date and time of a tweet

# %%
def date_time_split_convert(tweet_no):
    date_time_str = username_whole_twitter_info[str(tweet_no+1)]['created_at']
    date = date_time_str[:10] + ' ' + date_time_str[26:30]
    d = datetime.datetime.strptime(date_time_str[11:16], "%H:%M")
    time = d.strftime("%I:%M %p")
    return date, time

# %% [markdown]
# #### the following block fetches specific information such as date, time, favorite count, etc and creates a list of dictionaries, with each dictionary representing information of one tweet

# %%
tweets_list = list()
for i in range(len(username_whole_twitter_info)):
    tweet_info = dict()
    # calling date_time_split_convert() to get date and time
    tweet_info['Date'], tweet_info['Time'] = date_time_split_convert(i)
    tweet_info["Text"] = username_whole_twitter_info[str(i+1)]['text']
    tweet_info["Retweets"] = username_whole_twitter_info[str(i+1)]['retweet_count']
    tweet_info["Likes"] = username_whole_twitter_info[str(i+1)]['favorite_count']
    try:
        media = username_whole_twitter_info[str(i + 1)]['entities']['media']
        tweet_info['No._of_Images'] = len(media)
    except:
        tweet_info['No._of_Images'] = 'None'
    
    tweets_list.append(tweet_info)

# %% [markdown]
# #### the cell below creates a dataframe of the list created above

# %%
df = pd.DataFrame(tweets_list)

# %% [markdown]
# #### display of information of the tweets made by midasIIITD

# %%
df
# Out:
#                 Date  Likes No._of_Images  Retweets  \
# 0    Wed Apr 10 2019      0          None         2
# 1    Wed Apr 10 2019      3          None         3
# 2    Wed Apr 10 2019      2          None         1
# 3    Wed Apr 10 2019      1          None         0
# 4    Wed Apr 10 2019      0          None         1
# 5    Tue Apr 09 2019      0          None        14
# 6    Tue Apr 09 2019      0          None        36
# 7    Tue Apr 09 2019      0          None        17
# 8    Mon Apr 08 2019      0          None        15
# 9    Mon Apr 08 2019     18          None         2
# 10   Mon Apr 08 2019      5          None         0
# 11   Sun Apr 07 2019      0          None         0
# 12   Sun Apr 07 2019      0          None         0
# 13   Sun Apr 07 2019      1          None         1
# 14   Sun Apr 07 2019      5          None         2
# 15   Sun Apr 07 2019      5          None         1
# 16   Sun Apr 07 2019      6          None         1
# 17   Sun Apr 07 2019      7          None         1
# 18   Sat Apr 06 2019      0          None         2
# 19   Sat Apr 06 2019     18          None         3
# 20   Fri Apr 05 2019     11          None         1
# 21   Fri Apr 05 2019      0          None        16
# 22   Fri Apr 05 2019      0             1        11
# 23   Wed Apr 03 2019      0          None        59
# 24   Wed Apr 03 2019      0          None       873
# 25   Wed Apr 03 2019      0          None        16
# 26   Wed Apr 03 2019      0          None         4
# 27   Tue Apr 02 2019      8          None         1
# 28   Tue Apr 02 2019      5          None         1
# 29   Tue Apr 02 2019      0          None         7
# ..               ...    ...           ...       ...
# 317  Thu Aug 09 2018      0          None       265
# 318  Wed Aug 08 2018      2          None         1
# 319  Wed Aug 08 2018      3             1         1
# 320  Wed Aug 08 2018      0          None         1
# 321  Tue Aug 07 2018      0             1        40
# 322  Tue Aug 07 2018      1          None         1
# 323  Tue Aug 07 2018      1          None         1
# 324  Tue Aug 07 2018      1          None         1
# 325  Mon Aug 06 2018      0          None         0
# 326  Mon Aug 06 2018      0             1       103
# 327  Mon Aug 06 2018      0          None         0
# 328  Fri Aug 03 2018      6          None         1
# 329  Wed Aug 01 2018      5             1         1
# 330  Wed Aug 01 2018      0          None         4
# 331  Wed Aug 01 2018      0          None         4
# 332  Tue Jul 31 2018      1          None         0
# 333  Tue Jul 31 2018      0          None       264
# 334  Mon Jul 30 2018      0          None         2
# 335  Sat Jul 28 2018      0          None        57
# 336  Sat Jul 28 2018      0          None       105
# 337  Sat Jul 28 2018      0          None         7
# 338  Sat Jul 28 2018      0          None         6
# 339  Fri Jul 27 2018      3          None         2
# 340  Fri Jul 27 2018      8          None         2
# 341  Wed Jul 25 2018      5          None         1
# 342  Tue Jul 24 2018      2          None         1
# 343  Tue Jul 24 2018      2          None         1
# 344  Tue Jul 24 2018      4             1         1
# 345  Mon Jul 23 2018      3          None         1
# 346  Mon Jul 23 2018      7          None         4
#
#                                                   Text      Time
# 0    RT @RatnRajiv: @midasIIITD @IIITDelhi @Hitkul_...  06:00 PM
# 1    @midasIIITD lab is looking for motivated MTech...  05:05 PM
# 2    We will close the submission portal for submit...  04:47 PM
# 3    Clarification: Our earlier post which indicate...  09:01 AM
# 4    RT @IIITDelhi: Applications open for MTech (CB...  04:51 AM
# 5    RT @IIITDelhi: We are delighted to share that ...  04:45 PM
# 6    RT @Harvard: Professor Jelani Nelson founded A...  05:04 AM
# 7    RT @emnlp2019: For anyone interested in submit...  05:04 AM
# 8    RT @multimediaeval: Announcing the 2019 MediaE...  07:38 PM
# 9    Many Congratulations to @midasIIITD student, S...  07:08 AM
# 10   @midasIIITD thanks all students who have appea...  03:27 AM
# 11   @himanchalchandr Meanwhile, complete CV/NLP ta...  02:17 PM
# 12   @sayangdipto123 Submit as per the guideline ag...  02:17 PM
# 13   We request all students whose interview are sc...  11:43 AM
# 14   Other queries: "none of the Tweeter Apis give ...  06:55 AM
# 15   Other queries: "do we have to make two differe...  06:53 AM
# 16   Other queries: "If using Twitter api, it does ...  05:32 AM
# 17   Response to some queries asked by students on ...  05:29 AM
# 18   RT @kdnuggets: Top 8 #Free Must-Read #Books on...  05:11 PM
# 19   @nupur_baghel @PennDATS Congratulation @nupur_...  04:43 PM
# 20   We have emailed the task details to all candid...  04:08 PM
# 21   RT @rfpvjr: Our NAACL paper on polarization in...  04:05 AM
# 22   RT @kdnuggets: Effective Transfer Learning For...  04:04 AM
# 23   RT @stanfordnlp: What’s new in @Stanford CS224...  06:31 PM
# 24   RT @DeepMindAI: Today we're releasing a large-...  05:04 PM
# 25   RT @ylecun: Congratulations Jitendra Malik !\n...  09:03 AM
# 26   RT @IIITDelhi: Another chance to take admissio...  07:46 AM
# 27   Dear @midasIIITD internship candidates who hav...  04:20 AM
# 28   Looking forward to your paper submission to @I...  02:44 AM
# 29   RT @ngrams: Reproducibility in multimedia rese...  02:35 AM
# ..                                                 ...       ...
# 317  RT @TensorFlow: TensorFlow 1.10.0 has been rel...  05:59 AM
# 318  @midasIIITD is looking for motivated IIITD MTe...  11:30 AM
# 319  @IIITDelhi @ponguru @RatnRajiv The results of ...  05:53 AM
# 320  RT @IIITDelhi: @midasIIITD has secured rank 1 ...  05:45 AM
# 321  RT @kdnuggets: Comparison of Top 6 Python NLP ...  07:16 AM
# 322  Check more details of the 20th IEEE Internatio...  02:05 AM
# 323  MR2AMC@ISM 2018 will be organized by @RatnRaji...  01:58 AM
# 324  Our workshop proposal named, "MR2AMC: Multimod...  01:50 AM
# 325  @NUSComputing Congratulations Abdelhak and Pro...  05:48 PM
# 326  RT @goodfellow_ian: One of the most anticipate...  05:46 PM
# 327     @the_dhumketu Great to have you in @midasIIITD  06:06 AM
# 328  Congratulation @soujanyaporia for being appoin...  05:56 AM
# 329  @IIITDelhi @the_dhumketu Thanks team @midasIII...  11:47 AM
# 330  RT @IIITDelhi: Congratulations @midasIIITD int...  11:20 AM
# 331  RT @learning_pt: Profile of the 5 Indian under...  05:06 AM
# 332  Have a look at the list of accepted papers in ...  12:11 PM
# 333  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...  02:06 AM
# 334  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...  07:30 AM
# 335  RT @ylecun: Jitendra Malik, who directs FAIR-M...  11:07 AM
# 336  RT @kdnuggets: .@Bloomberg launches free cours...  06:14 AM
# 337  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...  06:13 AM
# 338  RT @IIITDelhi: We are delighted to announce th...  04:08 AM
# 339  Get ready for the annual technical fest of @II...  06:46 AM
# 340  Congratulations Dr. @RatnRajiv and team @midas...  04:07 AM
# 341  Congratulations MIDAS @midasIIITD intern Prakh...  05:14 AM
# 342    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm  10:33 AM
# 343  It feels great to be the part of @IIITDelhi. h...  10:12 AM
# 344  Thank you, @toonzratn for designing the logo o...  09:46 AM
# 345  We are on Facebook too. Like our page to get o...  04:25 PM
# 346  MIDAS is a group of researchers at IIIT-Delhi ...  12:53 PM
#
# [347 rows x 6 columns]
